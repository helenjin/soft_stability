# %%
import sys
sys.path.append("../src")
from data_utils import ImageNetSubset

# %%
dataset = ImageNetSubset("/home/antonxue/foo/data/imagenet_samples/imagenet_2_per_class/")

# %%
dataset[1341]
# Out:
# (tensor([[[-0.7333, -0.6627, -0.6314,  ..., -0.3647, -0.4667, -0.6235],
#           [-0.7725, -0.6392, -0.6157,  ..., -0.3098, -0.4588, -0.5922],
#           [-0.8118, -0.6314, -0.6157,  ..., -0.2863, -0.4745, -0.5686],
#           ...,
#           [-0.4745, -0.4902, -0.4980,  ..., -0.5451, -0.6078, -0.6157],
#           [-0.5451, -0.4588, -0.4588,  ..., -0.5686, -0.6000, -0.6078],
#           [-0.5529, -0.5137, -0.4588,  ..., -0.6000, -0.6000, -0.6078]],
#
#          [[-0.8353, -0.7255, -0.6784,  ..., -0.3804, -0.5451, -0.6784],
#           [-0.8510, -0.7176, -0.6627,  ..., -0.3098, -0.5373, -0.6471],
#           [-0.8745, -0.7020, -0.6627,  ..., -0.2706, -0.5608, -0.6314],
#           ...,
#           [-0.5059, -0.5137, -0.5294,  ..., -0.5529, -0.6235, -0.6314],
#           [-0.5686, -0.4824, -0.4824,  ..., -0.5765, -0.6235, -0.6392],
#           [-0.5843, -0.5373, -0.4902,  ..., -0.6078, -0.6235, -0.6392]],
#
# ...
